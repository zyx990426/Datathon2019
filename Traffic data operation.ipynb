# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import math

# %%
collision_data=pd.read_csv('pd_collisions_datasd.csv')
collision_data.head()
# Out:
#   report_id            date_time  police_beat  street_no street_dir  \
# 0    170166  2017-01-01 00:01:00          124       8300
# 1    170218  2017-01-01 00:01:00          325       8100
# 2    170101  2017-01-01 00:01:00          322       6400
# 3    170082  2017-01-01 00:01:00          935       5500
# 4    170097  2017-01-01 01:00:00          521       1000
#
#    street_name street_type cross_st_dir cross_st_name cross_st_type  \
# 0  CAM DEL ORO
# 1  ROYAL GORGE       DRIVE
# 2     CRAWFORD      STREET
# 3      VALERIO       TRAIL
# 4         11TH      AVENUE
#
#   violation_section violation_type  \
# 0          MISC-HAZ             VC
# 1             22107             VC
# 2          MISC-HAZ             VC
# 3          MISC-HAZ             VC
# 4             22107             VC
#
#                                          charge_desc  injured  killed  \
# 0  MISCELLANEOUS HAZARDOUS VIOLATIONS OF THE VEHI...        0       0
# ...

# %%
collision_data_cleaned=collision_data[['date_time', 'street_name', 'street_type', 'injured', 'killed']]

# %%
count = np.ones(collision_data_cleaned.shape[0])
collision_data_cleaned['count'] = count
del collision_data_cleaned['new_col']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
collision_data_cleaned.head()
# Out:
#              date_time  street_name street_type  injured  killed  count
# 0  2017-01-01 00:01:00  CAM DEL ORO                    0       0    1.0
# 1  2017-01-01 00:01:00  ROYAL GORGE       DRIVE        0       0    1.0
# 2  2017-01-01 00:01:00     CRAWFORD      STREET        0       0    1.0
# 3  2017-01-01 00:01:00      VALERIO       TRAIL        0       0    1.0
# 4  2017-01-01 01:00:00         11TH      AVENUE        0       0    1.0

# %%
collision_data_cleaned.head()
# Out:
#              date_time  street_name street_type  injured  killed  count
# 0  2017-01-01 00:01:00  CAM DEL ORO                    0       0    1.0
# 1  2017-01-01 00:01:00  ROYAL GORGE       DRIVE        0       0    1.0
# 2  2017-01-01 00:01:00     CRAWFORD      STREET        0       0    1.0
# 3  2017-01-01 00:01:00      VALERIO       TRAIL        0       0    1.0
# 4  2017-01-01 01:00:00         11TH      AVENUE        0       0    1.0

# %%
count_data=pd.read_csv('traffic_counts_datasd.csv')
count_data.head()
# Out:
#            id street_name             limits all_count northbound_count  \
# 0  01AV018207       01 AV      A ST - ASH ST                      18010
# 1  01AV015210       01 AV      A ST - ASH ST                      20060
# 2  01AV018213       01 AV      A ST - ASH ST                      19597
# 3  01AV088812       01 AV  ASH ST - BEECH ST                       2298
# 4  01AV068711       01 AV        B ST - A ST                      15625
#
#    southbound_count  eastbound_count  westbound_count  total_count  file_no  \
# 0               NaN              NaN              NaN        18010  0182-07
# 1               NaN              NaN              NaN        20060  0152-10
# 2               NaN              NaN              NaN        19597  0182-13
# 3               NaN              NaN              NaN         2298  0888-12
# 4               NaN              NaN              NaN        15625  0687-11
#
#             count_date
# 0  2007-03-13 00:00:00
# 1  2010-03-18 00:00:00
# ...

# %%
count_data_cleaned=count_data[['street_name', 'total_count','count_date']]
count_data_cleaned.head()
count_data_cleaned.rename({'count_date': 'date_time'},axis=1)
# Out:
#           street_name  total_count            date_time
# 0               01 AV        18010  2007-03-13 00:00:00
# 1               01 AV        20060  2010-03-18 00:00:00
# 2               01 AV        19597  2013-03-12 00:00:00
# 3               01 AV         2298  2012-12-11 00:00:00
# 4               01 AV        15625  2011-09-01 00:00:00
# 5               01 AV        13569  2014-02-11 00:00:00
# 6               01 AV        13389  2012-05-31 00:00:00
# 7               01 AV        13995  2015-06-17 00:00:00
# 8               01 AV        27450  2006-03-23 00:00:00
# 9               01 AV        22345  2009-03-31 00:00:00
# 10              01 AV        18742  2012-03-08 00:00:00
# 11              01 AV        24463  2015-04-30 00:00:00
# 12              01 AV        25715  2016-03-30 00:00:00
# 13              01 AV        10410  2008-01-08 00:00:00
# 14              01 AV        12905  2011-02-08 00:00:00
# 15              01 AV        11278  2014-02-11 00:00:00
# ...

# %%
grouped_collision=collision_data_cleaned.groupby('street_name').sum()
grouped_collision
# Out:
#                  injured  killed  count
# street_name
#  ARROYO ROSITA         1       0    1.0
#  EAST DR               1       0    1.0
#  FENTON PY             0       0    1.0
#  I-15 NB               1       0    1.0
#  MIRO CR               1       0    1.0
# 01:30:00 PM            0       0    1.0
# 01ST                  54       0   84.0
# 02ND                  11       0   30.0
# 03RD                  10       0   28.0
# 04TH                  70       0  105.0
# 05TH                  81       0  139.0
# 06TH                  96       0  147.0
# 06TH EX                0       0    1.0
# 07TH                  13       0   30.0
# 08TH                  12       0   34.0
# 09TH                  23       0   36.0
# 1-5 SB                 1       0    1.0
# 10:15:00 AM            0       0    1.0
# 10TH                  43       0   65.0
# 11TH                  40       0   55.0
# 11TH AV                0       0    1.0
# 11TH AVET              1       0    1.0
# ...

# %%
grouped_count=count_data_cleaned.groupby('street_name').sum()
grouped_count
# Out:
#                   total_count
# street_name
# 01 AV                  696037
# 02 AV                   47791
# 03 AV                   80911
# 04 AV                  708009
# 05 AV                  849199
# 06 AV                 1257625
# 07 AV                   59831
# 08 AV                   74704
# 09 AV                   53779
# 10 AV                  485243
# 11 AV                  438112
# 14 ST                    6466
# 16 ST                  212697
# 17 ST                   32491
# 19 ST                   49546
# 25 ST                  236581
# 26 ST                   58438
# 27 ST                   27442
# 28 ST                  542711
# 30  ST                   9713
# 30 ST                  718655
# 32 ST                  416495
# 33 ST                   74171
# 35 ST                  136294
# 36 ST                   26144
# 37 ST                    5191
# 38 ST                   38525
# 39 ST                    8238
# 40 ST                   27501
# ...

# %%
collision_data
# Out:
#       report_id            date_time  police_beat  street_no street_dir  \
# 0        170166  2017-01-01 00:01:00          124       8300
# 1        170218  2017-01-01 00:01:00          325       8100
# 2        170101  2017-01-01 00:01:00          322       6400
# 3        170082  2017-01-01 00:01:00          935       5500
# 4        170097  2017-01-01 01:00:00          521       1000
# 5        170220  2017-01-01 01:00:00          524       1000
# 6        170153  2017-01-01 01:18:00          437       2600
# 7        170035  2017-01-01 01:53:00          935       3900
# 8        170044  2017-01-01 01:58:00          115       9100
# 9        170042  2017-01-01 02:00:00          122       1600
# 10       170041  2017-01-01 02:00:00          122        900
# 11       170139  2017-01-01 02:03:00          434          0
# 12       170090  2017-01-01 04:10:00          813       2900
# 13       170073  2017-01-01 04:43:00          242      10000
# ...

# %%
# %matplotlib inline
y_value=list(grouped_collision['ratio'])
x_value=list(grouped_collision['street_name'])
plt.bar(x_value, y_value, color='red')
plt.show()
